# %%
import sqlalchemy
import pandas as pd
from datetime import datetime
import glob
from sqlalchemy import create_engine
import pymysql
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 as pg
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT
import pandas.io.sql as psql
import datetime as dt
import sys
import pymysql

# %%
# create engine for load data from pandas
engine = create_engine('postgresql://operator:Mimoza2019@192.168.55.55:5432/anamnez_copy')
dbConnection    = engine.connect()
#connection to use with raw sql
connection = pg.connect("host='192.168.55.55' dbname=anamnez_copy user=operator password='Mimoza2019'")
connection.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT);
cursor = connection.cursor()

# %%
tableName = "reestr_staging"

# Пример пути all_files = glob.glob("F:/anamnez/in/**/ПЗ*.csv", recursive=True)
#pathes=["F:/anamnez/in/2020.03.20/**/ПЗ*.csv","F:/anamnez/in/2020.05.01/10 не вігрузило пз 38397840/**/ПЗ*.csv","F:/anamnez/in/2020.08.12/15/**/*реалізація*.xlsx","F:/anamnez/in/2020.08.12/46/**/*реалізація*.xlsx"]
#pathes=["F:/anamnez/in/2020.08.12/46/**/41189553 реалізація*.xlsx","F:/anamnez/in/2020.05.01/10 не вігрузило пз 38397840/**/пз 41189553.csv",]
pathes=["/home/das/db_develop/nalog_copy/2019.05.07/**/зобов'язання.*",
        "/home/das/db_develop/nalog_copy/2020.03.20/**/*ПЗ*.*",
        "/home/das/db_develop/nalog_copy/2020.05.01/**/*пз*.*",
        "/home/das/db_develop/nalog_copy/2020.05.20/**/*пз*.*",
        "/home/das/db_develop/nalog_copy/2020.08.12/**/*реалізація*.*",
        "/home/das/db_develop/nalog_copy/2020.11.09/**/*реалізація*.*"
       ]
all_pths=[]
for pth in pathes:
    for p in glob.glob(pth, recursive=True):
        #print(p)
        all_pths.append(p)
    #print(len(glob.glob(pth, recursive=True)))
all_pths= sorted(all_pths)
print(len(all_pths))
print(all_pths)
# Out:
# 224
# ["/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/19156740/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/22954177/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/24908218 (ЮГОВОСТОК)/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/25046658/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/25288344 (КИЙ-В)/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/33358979/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/36303331/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/37069288 (ТЕХМА)/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/38388904/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/39527778/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/40295657 (МЕТСЕЙЛ)/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/40946602 (ЭФЕС)/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/35935562/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/36068718/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38185522/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38235159/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38453790/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38797324/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39031869/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39304165/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39386468/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/41047380/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/19156740/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/22954177/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/24908218/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/25046658/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/25288344/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/33358979/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/35935562/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/36068718/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/36303331/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/37069288/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38185522/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38235159/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38388904/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38453790/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38797324/зобов'язання.xls", "/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39031869/зобов'язанн ...

# %%
for pth in all_pths:
    df_firms_in_base = pd.read_sql('select seller_edrpou as edrpou, max(ordering_date) AS maxdate from '+tableName+' GROUP BY seller_edrpou', con=dbConnection)
    db_edrpous = []
    if not df_firms_in_base.empty :
        db_edrpous=df_firms_in_base['edrpou'].tolist()
    all_files = glob.glob(pth, recursive=True)
    for filename in all_files:
        print("Work with " + filename +": ")
        if (filename.find('.csv')>0):
            print("Read csv file")
            frame = pd.read_csv(filename, engine="python", encoding="cp1251", sep=';', decimal=",")
            frame['Дата виписки'] = pd.to_datetime(frame['Дата виписки'],format='%d.%m.%Y', errors='raise')
        else:
            print("Read excel file")
            if (filename.find('.xls')>0):
                frame = pd.read_excel(filename)
            else:
                print("Wrong file type")
                exit()
        
        frame['Дата виписки'] = frame['Дата виписки'].dt.strftime('%Y-%m-%d')
        frame = frame.rename(columns={ \
                                      "Область (Продавець)": "Регіон (Продавець)", \
                                      "Податковий № (Продавець)": "Податковий номер (Продавець)", \
                                      "Область (Покупець)": "Регіон (Покупець)", \
                                      "Податковий № (Покупець)":"Податковий номер (Покупець)", \
                                      "Реєстраційний №":"Реєстр. номер у ЄРПН", \
                                      "Номер ПН/РК":"№ ПН", \
                                      "Ціна постачання одиниці товару / послуги без урахування податку на додану вартість":"Ціна постачання одиниці товару/послуги без ПДВ"})
        frame_rows_orig = frame.shape[0]
        frame.drop_duplicates(subset=['Податковий номер (Продавець)', 'Податковий номер (Покупець)', 'Номенклатура товарів/послуг','Кількість (об’єм , обсяг)','Ціна постачання одиниці товару/послуги без ПДВ'])
        frame_rows_nodup = frame.shape[0]
        print("Deleted " + str(frame_rows_orig - frame_rows_nodup)  +  " duplicates")
        frame.drop('Статус ПН/РК', axis=1, errors='ignore', inplace=True)
        frame.drop('Виключено', axis=1, errors='ignore', inplace=True)
        frame.drop('Обсяги постачання (база оподаткування) без урахування податку на додану вартість', axis=1, errors='ignore', inplace=True)
        print("Rows count: "+ str(len(frame['Дата виписки'])))
        frame = frame.rename(columns={
                'Iдентифікатор документа': 'doc_id',
            	'Регіон (Продавець)':'seller_region',
                'Район (Продавець)':'seller_rayon',
                'Податковий номер (Продавець)': 'seller_edrpou',
                'ІПН (Продавець)': 'seller_ipn',
                'Найменування/ПІБ (Продавець)': 'seller_name',
                'Стан (Продавець)': 'seller_state',
                'Регіон (Покупець)': 'buyer_region',
                'Район (Покупець)': 'buyer_rayon',
                'Податковий номер (Покупець)': 'buyer_edrpou',
                'ІПН (Покупець)': 'buyer_ipn',
                'Найменування/ПІБ (Покупець)': 'buyer_name',
                'Стан (Покупець)': 'buyer_state',
                'Реєстр. номер у ЄРПН': 'reestr_number',
                '№ ПН': 'nn_number',
                'Дата виписки': 'ordering_date',
                'Дата реєстрації': 'registration_date',
                'Загальна сума коштів що підлягає сплаті': 'total_pay_cost',
                'Сума ПДВ': 'pdv_summ',
                'Обсяг операцій за ставкою 20%': '20_percent_count',
                'Обсяг операцій за ставкою 7%': '7_percent_count',
                'Кількість РК': 'rk_count',
                'Сума коригування': 'correction_cost',
                'Ціна постач.одиниці РК': 'one_rk_cost',
                'Номенклатура товарів/послуг': 'product_name',
                'Код УКТЗЕД': 'product_code',
                'Одиниця виміру товару/ послуги': 'unit',
                'Кількість (об’єм , обсяг)': 'count',
                'Ціна постачання одиниці товару/послуги без ПДВ': 'one_product_cost'
                })
        #frame = frame.astype({'seller_edrpou': int,'buyer_edrpou': int})
        frame['seller_edrpou'].replace({0.0:0})
        frame['buyer_edrpou'].replace({0.0:0})
        if 'reestr_number' in frame.columns:
            frame['reestr_number'].replace({0.0:0})
        frame['seller_edrpou'].fillna(value=0,inplace=True)
        frame['buyer_edrpou'].fillna(value=0,inplace=True)
        frame['hash'] = frame.apply(lambda x: hash(tuple(x)), axis = 1)
        if len(frame) > 0:
            file_edrpou=int(min(frame['seller_edrpou']))
            if file_edrpou in db_edrpous:
                print("DB contains edrpou: "+ str(file_edrpou))
                min_file_date = str(min(frame['ordering_date']))
                max_db_date = str(df_firms_in_base[df_firms_in_base['edrpou'] == file_edrpou]['maxdate'].iloc[0])
                print("Max date in db: "+ max_db_date)
                print("Min date in file: "+min_file_date)
                if (max_db_date > min_file_date):
                    print ("Conflict !!!")
                    frame=frame[frame['ordering_date']>str(max_db_date)]
                    print("Records count for import: " + str(len(frame['ordering_date'])))
                    if len(frame) > 0:
                        print("Now min date in file: "+str(min(frame['ordering_date'])))
                        frame.to_sql(tableName, dbConnection, if_exists='append', index=False)
                else:  # if no conflicts
                    print("There are no conflicts. Doing import whole file...")
                    print("Records count for import: " + str(frame.shape[0]))
                    frame.to_sql(tableName, dbConnection, if_exists='append', index=False)
            else:  #if no data in db
                print("No data in db. Doing import whole file...")
                print("Records count for import: " + str(frame.shape[0]))
                frame.to_sql(tableName, dbConnection, if_exists='append', index=False)
            print("Done.")
        else:
            print("No data for period...")
print('Work finished')
# Out:
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/19156740/зобов'язання.xls:
# Read excel file
# WARNING *** file size (223770) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 92
# No data in db. Doing import whole file...
# Records count for import: 92
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/22954177/зобов'язання.xls:
# Read excel file
# WARNING *** file size (466951) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 615
# No data in db. Doing import whole file...
# Records count for import: 615
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/24908218 (ЮГОВОСТОК)/зобов'язання.xls:
# Read excel file
# WARNING *** file size (302869) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 167
# No data in db. Doing import whole file...
# Records count for import: 167
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/25046658/зобов'язання.xls:
# Read excel file
# WARNING *** file size (10626347) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 15062
# No data in db. Doing import whole file...
# Records count for import: 15062
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/25288344 (КИЙ-В)/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2752130) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 5182
# No data in db. Doing import whole file...
# Records count for import: 5182
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/33358979/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2765247) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 3535
# No data in db. Doing import whole file...
# Records count for import: 3535
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/36303331/зобов'язання.xls:
# Read excel file
# WARNING *** file size (798030) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 756
# No data in db. Doing import whole file...
# Records count for import: 756
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/37069288 (ТЕХМА)/зобов'язання.xls:
# Read excel file
# WARNING *** file size (5383274) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 7690
# No data in db. Doing import whole file...
# Records count for import: 7690
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/38388904/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1451786) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2101
# No data in db. Doing import whole file...
# Records count for import: 2101
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/39527778/зобов'язання.xls:
# Read excel file
# WARNING *** file size (793553) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1234
# No data in db. Doing import whole file...
# Records count for import: 1234
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/40295657 (МЕТСЕЙЛ)/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1455321) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2268
# No data in db. Doing import whole file...
# Records count for import: 2268
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/40946602 (ЭФЕС)/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1454539) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1630
# No data in db. Doing import whole file...
# Records count for import: 1630
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/35935562/зобов'язання.xls:
# Read excel file
# WARNING *** file size (222336) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 145
# No data in db. Doing import whole file...
# Records count for import: 145
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/36068718/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1451627) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1714
# No data in db. Doing import whole file...
# Records count for import: 1714
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38185522/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1448680) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2175
# No data in db. Doing import whole file...
# Records count for import: 2175
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38235159/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1453503) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1592
# No data in db. Doing import whole file...
# Records count for import: 1592
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38453790/зобов'язання.xls:
# Read excel file
# WARNING *** file size (470680) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 450
# No data in db. Doing import whole file...
# Records count for import: 450
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38797324/зобов'язання.xls:
# Read excel file
# WARNING *** file size (10623314) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 15566
# No data in db. Doing import whole file...
# Records count for import: 15566
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39031869/зобов'язання.xls:
# Read excel file
# WARNING *** file size (224513) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 159
# No data in db. Doing import whole file...
# Records count for import: 159
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39304165/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1455351) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1654
# No data in db. Doing import whole file...
# Records count for import: 1654
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39386468/зобов'язання.xls:
# Read excel file
# WARNING *** file size (805669) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 803
# No data in db. Doing import whole file...
# Records count for import: 803
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/41047380/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2761952) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 3875
# No data in db. Doing import whole file...
# Records count for import: 3875
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/19156740/зобов'язання.xls:
# Read excel file
# WARNING *** file size (224291) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 153
# DB contains edrpou: 19156740
# Max date in db: 2018-08-27
# Min date in file: 2016-12-22
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/22954177/зобов'язання.xls:
# Read excel file
# WARNING *** file size (792592) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1155
# DB contains edrpou: 22954177
# Max date in db: 2018-09-05
# Min date in file: 2016-12-23
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/24908218/зобов'язання.xls:
# Read excel file
# WARNING *** file size (469448) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 543
# DB contains edrpou: 24908218
# Max date in db: 2018-08-10
# Min date in file: 2016-12-13
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/25046658/зобов'язання.xls:
# Read excel file
# WARNING *** file size (10630756) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 20501
# DB contains edrpou: 25046658
# Max date in db: 2018-08-31
# Min date in file: 2016-11-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/25288344/зобов'язання.xls:
# Read excel file
# WARNING *** file size (5371849) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 7008
# DB contains edrpou: 25288344
# Max date in db: 2018-08-23
# Min date in file: 2016-12-09
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/33358979/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2761645) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 4998
# DB contains edrpou: 33358979
# Max date in db: 2018-08-29
# Min date in file: 2016-12-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/35935562/зобов'язання.xls:
# Read excel file
# WARNING *** file size (301755) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 257
# DB contains edrpou: 35935562
# Max date in db: 2018-08-13
# Min date in file: 2016-12-29
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/36068718/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1450634) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2613
# DB contains edrpou: 36068718
# Max date in db: 2018-08-31
# Min date in file: 2016-12-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/36303331/зобов'язання.xls:
# Read excel file
# WARNING *** file size (801483) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1063
# DB contains edrpou: 36303331
# Max date in db: 2018-08-28
# Min date in file: 2016-12-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/37069288/зобов'язання.xls:
# Read excel file
# WARNING *** file size (5396318) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 9336
# DB contains edrpou: 37069288
# Max date in db: 2018-08-29
# Min date in file: 2016-12-22
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38185522/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2760466) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 3223
# DB contains edrpou: 38185522
# Max date in db: 2018-09-07
# Min date in file: 2017-01-04
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38235159/зобов'язання.xls:
# Read excel file
# WARNING *** file size (799040) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1471
# DB contains edrpou: 38235159
# Max date in db: 2018-08-15
# Min date in file: 2016-12-30
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38388904/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2764197) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 3629
# DB contains edrpou: 38388904
# Max date in db: 2018-08-31
# Min date in file: 2016-12-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38453790/зобов'язання.xls:
# Read excel file
# WARNING *** file size (472074) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 495
# DB contains edrpou: 38453790
# Max date in db: 2018-08-31
# Min date in file: 2016-12-28
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38797324/зобов'язання.xls:
# Read excel file
# WARNING *** file size (10630640) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 19370
# DB contains edrpou: 38797324
# Max date in db: 2018-08-31
# Min date in file: 2016-12-19
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39031869/зобов'язання.xls:
# Read excel file
# WARNING *** file size (305199) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 189
# DB contains edrpou: 39031869
# Max date in db: 2018-08-09
# Min date in file: 2017-01-10
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39304165/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1455521) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1470
# DB contains edrpou: 39304165
# Max date in db: 2018-08-14
# Min date in file: 2016-11-30
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39386468/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1457375) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1421
# DB contains edrpou: 39386468
# Max date in db: 2018-08-28
# Min date in file: 2016-12-28
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39527778/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1448205) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1767
# DB contains edrpou: 39527778
# Max date in db: 2018-08-31
# Min date in file: 2016-12-21
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/40295657/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1454108) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2378
# DB contains edrpou: 40295657
# Max date in db: 2018-08-10
# Min date in file: 2016-12-27
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/40946602/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1455990) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1740
# DB contains edrpou: 40946602
# Max date in db: 2018-08-30
# Min date in file: 2017-01-13
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/41047380/зобов'язання.xls:
# Read excel file
# WARNING *** file size (797674) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 908
# DB contains edrpou: 41047380
# Max date in db: 2018-08-21
# Min date in file: 2017-02-08
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/19156740/зобов'язання.xls:
# Read excel file
# WARNING *** file size (223727) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 92
# DB contains edrpou: 19156740
# Max date in db: 2018-08-27
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/22954177/зобов'язання.xls:
# Read excel file
# WARNING *** file size (464675) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 636
# DB contains edrpou: 22954177
# Max date in db: 2018-09-05
# Min date in file: 2017-12-31
# Conflict !!!
# Records count for import: 21
# Now min date in file: 2018-09-07
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/25046658/зобов'язання.xls:
# Read excel file
# WARNING *** file size (10626450) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 15448
# DB contains edrpou: 25046658
# Max date in db: 2018-08-31
# Min date in file: 2017-11-10
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/35935562/зобов'язання.xls:
# Read excel file
# WARNING *** file size (221963) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 147
# DB contains edrpou: 35935562
# Max date in db: 2018-08-13
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 2
# Now min date in file: 2018-08-29
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/36068718/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1451604) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1740
# DB contains edrpou: 36068718
# Max date in db: 2018-08-31
# Min date in file: 2017-12-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/36303331/зобов'язання.xls:
# Read excel file
# WARNING *** file size (802089) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 790
# DB contains edrpou: 36303331
# Max date in db: 2018-08-28
# Min date in file: 2017-12-27
# Conflict !!!
# Records count for import: 12
# Now min date in file: 2018-08-30
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/37069288/зобов'язання.xls:
# Read excel file
# WARNING *** file size (5390759) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 7963
# DB contains edrpou: 37069288
# Max date in db: 2018-08-29
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 91
# Now min date in file: 2018-08-30
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/38185522/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1447833) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2246
# DB contains edrpou: 38185522
# Max date in db: 2018-09-07
# Min date in file: 2018-01-03
# Conflict !!!
# Records count for import: 71
# Now min date in file: 2018-09-10
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/38235159/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1453985) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1728
# DB contains edrpou: 38235159
# Max date in db: 2018-08-15
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 136
# Now min date in file: 2018-08-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/38388904/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1452758) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2107
# DB contains edrpou: 38388904
# Max date in db: 2018-08-31
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/38797324/зобов'язання.xls:
# Read excel file
# WARNING *** file size (10622573) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 16060
# DB contains edrpou: 38797324
# Max date in db: 2018-08-31
# Min date in file: 2017-12-11
# Conflict !!!
# Records count for import: 438
# Now min date in file: 2018-09-03
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/39031869/зобов'язання.xls:
# Read excel file
# WARNING *** file size (309227) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 215
# DB contains edrpou: 39031869
# Max date in db: 2018-08-09
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 56
# Now min date in file: 2018-08-20
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21-1/39304165/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1457361) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1755
# DB contains edrpou: 39304165
# Max date in db: 2018-08-14
# Min date in file: 2017-01-31
# Conflict !!!
# Records count for import: 101
# Now min date in file: 2018-08-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/19156740/зобов'язання.xls:
# Read excel file
# Deleted 0 duplicates
# Rows count: 92
# DB contains edrpou: 19156740
# Max date in db: 2018-08-27
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/22954177/зобов'язання.xls:
# Read excel file
# WARNING *** file size (464675) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 636
# DB contains edrpou: 22954177
# Max date in db: 2018-09-14
# Min date in file: 2017-12-31
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/24908218/зобов'язання.xls:
# Read excel file
# WARNING *** file size (303693) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 171
# DB contains edrpou: 24908218
# Max date in db: 2018-08-10
# Min date in file: 2017-12-19
# Conflict !!!
# Records count for import: 4
# Now min date in file: 2018-08-21
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/25046658/зобов'язання.xls:
# Read excel file
# WARNING *** file size (10626450) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 15448
# DB contains edrpou: 25046658
# Max date in db: 2018-08-31
# Min date in file: 2017-11-10
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/25288344/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2751828) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 5550
# DB contains edrpou: 25288344
# Max date in db: 2018-08-23
# Min date in file: 2017-12-13
# Conflict !!!
# Records count for import: 195
# Now min date in file: 2018-08-27
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/35935562/зобов'язання.xls:
# Read excel file
# WARNING *** file size (221963) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 147
# DB contains edrpou: 35935562
# Max date in db: 2018-08-31
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/36068718/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1451604) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1740
# DB contains edrpou: 36068718
# Max date in db: 2018-08-31
# Min date in file: 2017-12-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/36303331/зобов'язання.xls:
# Read excel file
# WARNING *** file size (802089) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 790
# DB contains edrpou: 36303331
# Max date in db: 2018-08-31
# Min date in file: 2017-12-27
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/37069288/зобов'язання.xls:
# Read excel file
# WARNING *** file size (5390759) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 7963
# DB contains edrpou: 37069288
# Max date in db: 2018-09-05
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/38185522/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1447833) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2246
# DB contains edrpou: 38185522
# Max date in db: 2018-09-17
# Min date in file: 2018-01-03
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/38235159/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1453985) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1728
# DB contains edrpou: 38235159
# Max date in db: 2018-08-31
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/38388904/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1452758) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2107
# DB contains edrpou: 38388904
# Max date in db: 2018-08-31
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/38453790/зобов'язання.xls:
# Read excel file
# Deleted 0 duplicates
# Rows count: 450
# DB contains edrpou: 38453790
# Max date in db: 2018-08-31
# Min date in file: 2017-12-05
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/38797324/зобов'язання.xls:
# Read excel file
# Deleted 0 duplicates
# Rows count: 16060
# DB contains edrpou: 38797324
# Max date in db: 2018-09-11
# Min date in file: 2017-12-11
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/39031869/зобов'язання.xls:
# Read excel file
# WARNING *** file size (309227) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 215
# DB contains edrpou: 39031869
# Max date in db: 2018-08-29
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/39304165/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1457361) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1755
# DB contains edrpou: 39304165
# Max date in db: 2018-08-31
# Min date in file: 2017-01-31
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/39386468/зобов'язання.xls:
# Read excel file
# WARNING *** file size (805818) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 819
# DB contains edrpou: 39386468
# Max date in db: 2018-08-28
# Min date in file: 2017-12-26
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/39527778/зобов'язання.xls:
# Read excel file
# WARNING *** file size (795414) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1250
# DB contains edrpou: 39527778
# Max date in db: 2018-08-31
# Min date in file: 2017-12-21
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/40295657/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1451902) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 2413
# DB contains edrpou: 40295657
# Max date in db: 2018-08-10
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 145
# Now min date in file: 2018-08-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/40946602/зобов'язання.xls:
# Read excel file
# WARNING *** file size (1453086) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 1703
# DB contains edrpou: 40946602
# Max date in db: 2018-08-30
# Min date in file: 2017-12-18
# Conflict !!!
# Records count for import: 12
# Now min date in file: 2018-08-31
# Done.
# Work with /home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/21/41047380/зобов'язання.xls:
# Read excel file
# WARNING *** file size (2764126) not 512 + multiple of sector size (512)
# Deleted 0 duplicates
# Rows count: 4050
# DB contains edrpou: 41047380
# Max date in db: 2018-08-21
# Min date in file: 2017-12-16
# Conflict !!!
# Records count for import: 161
# Now min date in file: 2018-08-22
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/25046658/ПЗ 01.01.2019-01.06.2019.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 8459
# DB contains edrpou: 25046658
# Max date in db: 2018-08-31
# Min date in file: 2019-01-02
# There are no conflicts. Doing import whole file...
# Records count for import: 8459
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/25046658/ПЗ 01.01.2019-01.06.2019.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 8459
# DB contains edrpou: 25046658
# Max date in db: 2019-05-29
# Min date in file: 2019-01-02
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/25046658/ПЗ 01.06.2019-19.032020.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 19820
# DB contains edrpou: 25046658
# Max date in db: 2019-05-29
# Min date in file: 2019-06-02
# There are no conflicts. Doing import whole file...
# Records count for import: 19820
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/25046658/ПЗ 01.06.2019-19.032020.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 19820
# DB contains edrpou: 25046658
# Max date in db: 2020-03-17
# Min date in file: 2019-06-02
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/31955805/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 5898
# No data in db. Doing import whole file...
# Records count for import: 5898
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/32662713/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 246
# No data in db. Doing import whole file...
# Records count for import: 246
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/32662713/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 246
# DB contains edrpou: 32662713
# Max date in db: 2020-02-25
# Min date in file: 2019-01-14
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/32858983/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 4676
# No data in db. Doing import whole file...
# Records count for import: 4676
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/32858983/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 4676
# DB contains edrpou: 32858983
# Max date in db: 2020-03-16
# Min date in file: 2019-01-01
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/35935562/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 350
# DB contains edrpou: 35935562
# Max date in db: 2018-08-31
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 350
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/35935562/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 350
# DB contains edrpou: 35935562
# Max date in db: 2020-03-11
# Min date in file: 2019-01-03
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/36068718/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 1801
# DB contains edrpou: 36068718
# Max date in db: 2018-08-31
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 1801
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/36997771/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 384
# No data in db. Doing import whole file...
# Records count for import: 384
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/36997771/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 384
# DB contains edrpou: 36997771
# Max date in db: 2020-03-12
# Min date in file: 2019-01-29
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/37725526/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 738
# No data in db. Doing import whole file...
# Records count for import: 738
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/37725526/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 738
# DB contains edrpou: 37725526
# Max date in db: 2020-02-27
# Min date in file: 2019-01-22
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38185522/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 3985
# DB contains edrpou: 38185522
# Max date in db: 2018-09-17
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 3985
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38235159/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 1858
# DB contains edrpou: 38235159
# Max date in db: 2018-08-31
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 1858
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38264719/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 3903
# No data in db. Doing import whole file...
# Records count for import: 3903
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38264719/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 3903
# DB contains edrpou: 38264719
# Max date in db: 2020-03-18
# Min date in file: 2019-01-02
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38388904/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 3834
# DB contains edrpou: 38388904
# Max date in db: 2018-08-31
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 3834
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38388904/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 3834
# DB contains edrpou: 38388904
# Max date in db: 2020-03-16
# Min date in file: 2019-01-03
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38453790/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 1472
# DB contains edrpou: 38453790
# Max date in db: 2018-08-31
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 1472
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38797324/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 20178
# DB contains edrpou: 38797324
# Max date in db: 2018-09-11
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 20178
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38896207/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 237
# No data in db. Doing import whole file...
# Records count for import: 237
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/38896207/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 237
# DB contains edrpou: 38896207
# Max date in db: 2020-02-29
# Min date in file: 2019-01-15
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/39031869/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 1081
# DB contains edrpou: 39031869
# Max date in db: 2018-08-29
# Min date in file: 2019-01-14
# There are no conflicts. Doing import whole file...
# Records count for import: 1081
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/39043764/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 1859
# No data in db. Doing import whole file...
# Records count for import: 1859
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/39043764/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1859
# DB contains edrpou: 39043764
# Max date in db: 2020-02-28
# Min date in file: 2019-01-02
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/39185764/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 1290
# No data in db. Doing import whole file...
# Records count for import: 1290
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/39185764/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1290
# DB contains edrpou: 39185764
# Max date in db: 2020-03-05
# Min date in file: 2019-01-03
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/39773126/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 4781
# No data in db. Doing import whole file...
# Records count for import: 4781
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/39773126/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 4781
# DB contains edrpou: 39773126
# Max date in db: 2020-03-13
# Min date in file: 2019-01-03
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/40505181/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 422
# No data in db. Doing import whole file...
# Records count for import: 422
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/40505181/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 422
# DB contains edrpou: 40505181
# Max date in db: 2020-02-29
# Min date in file: 2019-01-04
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/41047380/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 7197
# DB contains edrpou: 41047380
# Max date in db: 2018-08-31
# Min date in file: 2019-01-03
# There are no conflicts. Doing import whole file...
# Records count for import: 7197
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/41455095/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 588
# No data in db. Doing import whole file...
# Records count for import: 588
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/41455095/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 588
# DB contains edrpou: 41455095
# Max date in db: 2020-02-24
# Min date in file: 2019-01-09
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/41881578/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 14
# No data in db. Doing import whole file...
# Records count for import: 14
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/41881578/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 14
# DB contains edrpou: 41881578
# Max date in db: 2020-02-28
# Min date in file: 2019-05-23
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/42121082/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 30
# No data in db. Doing import whole file...
# Records count for import: 30
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/42121082/ПЗ.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 30
# DB contains edrpou: 42121082
# Max date in db: 2020-01-20
# Min date in file: 2019-01-03
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.03.20/DropMeFiles_9GMxo/42918383/ПЗ.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 449
# No data in db. Doing import whole file...
# Records count for import: 449
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 36703454.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 2406
# No data in db. Doing import whole file...
# Records count for import: 2406
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 38133170.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 159
# No data in db. Doing import whole file...
# Records count for import: 159
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 38397840.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 37781
# No data in db. Doing import whole file...
# Records count for import: 37781
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 39120419.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 7598
# No data in db. Doing import whole file...
# Records count for import: 7598
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 39781472.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 8644
# No data in db. Doing import whole file...
# Records count for import: 8644
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 40109330.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 2137
# No data in db. Doing import whole file...
# Records count for import: 2137
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 40380511.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 12847
# No data in db. Doing import whole file...
# Records count for import: 12847
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 40407323.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 1611
# No data in db. Doing import whole file...
# Records count for import: 1611
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 41189553.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 28714
# No data in db. Doing import whole file...
# Records count for import: 28714
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.01/10 не вігрузило пз 38397840/пз 41987990.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 179
# No data in db. Doing import whole file...
# Records count for import: 179
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.20/import/пз 38133170.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 224
# No data in db. Doing import whole file...
# Records count for import: 224
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.20/import/пз 40380511.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 15078
# DB contains edrpou: 40380511
# Max date in db: 2020-04-15
# Min date in file: 2019-01-02
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.05.20/import/пз 41189553.csv:
# Read csv file
# Deleted 0 duplicates
# Rows count: 42140
# DB contains edrpou: 41189553
# Max date in db: 2020-04-24
# Min date in file: 2019-01-02
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/14307417 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 2649
# No data in db. Doing import whole file...
# Records count for import: 2649
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/32739728 реалізація МНОГО.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 15537
# No data in db. Doing import whole file...
# Records count for import: 15537
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/35031425 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 227
# No data in db. Doing import whole file...
# Records count for import: 227
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/36470766 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 581
# No data in db. Doing import whole file...
# Records count for import: 581
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/37827970 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 998
# No data in db. Doing import whole file...
# Records count for import: 998
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/38767347 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 43
# No data in db. Doing import whole file...
# Records count for import: 43
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/39274670 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 43
# No data in db. Doing import whole file...
# Records count for import: 43
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/39966290 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 606
# No data in db. Doing import whole file...
# Records count for import: 606
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/40429059 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 115
# No data in db. Doing import whole file...
# Records count for import: 115
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/41930148 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 222
# No data in db. Doing import whole file...
# Records count for import: 222
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/42174586 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 4
# No data in db. Doing import whole file...
# Records count for import: 4
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/42298183 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 36
# No data in db. Doing import whole file...
# Records count for import: 36
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/43336690 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 17
# No data in db. Doing import whole file...
# Records count for import: 17
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/15/43486282 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 14
# No data in db. Doing import whole file...
# Records count for import: 14
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/19396526 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1214
# No data in db. Doing import whole file...
# Records count for import: 1214
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/22412950 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 24852
# No data in db. Doing import whole file...
# Records count for import: 24852
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/25046658 реалізація МНОГО.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 22681
# DB contains edrpou: 25046658
# Max date in db: 2020-03-17
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 6935
# Now min date in file: 2020-03-18
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/25268212 реалізація ОЧЕНЬ МНОГО.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 58885
# No data in db. Doing import whole file...
# Records count for import: 58885
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/30209891 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 203
# No data in db. Doing import whole file...
# Records count for import: 203
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/30663762 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1570
# No data in db. Doing import whole file...
# Records count for import: 1570
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/31024503 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 346
# No data in db. Doing import whole file...
# Records count for import: 346
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/31301979 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 156
# No data in db. Doing import whole file...
# Records count for import: 156
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/31955805 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 5440
# DB contains edrpou: 31955805
# Max date in db: 2020-03-13
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 1969
# Now min date in file: 2020-03-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/35935562 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 305
# DB contains edrpou: 35935562
# Max date in db: 2020-03-11
# Min date in file: 2019-08-15
# Conflict !!!
# Records count for import: 105
# Now min date in file: 2020-03-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/36068718 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 995
# DB contains edrpou: 36068718
# Max date in db: 2020-03-17
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 159
# ...
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 5106
# Now min date in file: 2020-03-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/39031869 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1120
# DB contains edrpou: 39031869
# Max date in db: 2020-02-28
# Min date in file: 2019-08-13
# Conflict !!!
# Records count for import: 350
# Now min date in file: 2020-03-02
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/39043764 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1014
# DB contains edrpou: 39043764
# Max date in db: 2020-02-28
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 146
# Now min date in file: 2020-03-02
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/39120419 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 5852
# DB contains edrpou: 39120419
# Max date in db: 2020-04-15
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 1645
# Now min date in file: 2020-04-17
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/39185764 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 997
# DB contains edrpou: 39185764
# Max date in db: 2020-03-05
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 295
# Now min date in file: 2020-03-10
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/39773126 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 5447
# DB contains edrpou: 39773126
# Max date in db: 2020-03-13
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 2304
# Now min date in file: 2020-03-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/39781472 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 4777
# DB contains edrpou: 39781472
# Max date in db: 2020-04-15
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 691
# Now min date in file: 2020-04-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/40109330 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 815
# DB contains edrpou: 40109330
# Max date in db: 2020-04-08
# Min date in file: 2019-08-15
# Conflict !!!
# Records count for import: 156
# Now min date in file: 2020-04-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/40380511 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 14780
# DB contains edrpou: 40380511
# Max date in db: 2020-04-15
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 4203
# Now min date in file: 2020-04-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/40407323 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 656
# DB contains edrpou: 40407323
# Max date in db: 2020-04-28
# Min date in file: 2019-08-14
# Conflict !!!
# Records count for import: 65
# Now min date in file: 2020-04-30
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/41047380 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 6115
# DB contains edrpou: 41047380
# Max date in db: 2020-03-11
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 2377
# Now min date in file: 2020-03-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/41089457 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 9923
# No data in db. Doing import whole file...
# Records count for import: 9923
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/41189553 реалізація ВПП.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 23523
# DB contains edrpou: 41189553
# Max date in db: 2020-04-24
# Min date in file: 2020-01-02
# Conflict !!!
# Records count for import: 11685
# Now min date in file: 2020-04-27
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/41455095 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 459
# DB contains edrpou: 41455095
# Max date in db: 2020-02-24
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 184
# Now min date in file: 2020-03-02
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/41987990 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 213
# DB contains edrpou: 41987990
# Max date in db: 2020-04-29
# Min date in file: 2019-08-13
# Conflict !!!
# Records count for import: 112
# Now min date in file: 2020-05-13
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/42346980 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 14754
# No data in db. Doing import whole file...
# Records count for import: 14754
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/42547583 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 26
# No data in db. Doing import whole file...
# Records count for import: 26
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/42853693 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 2887
# No data in db. Doing import whole file...
# Records count for import: 2887
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.08.12/46/42918383 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 821
# DB contains edrpou: 42918383
# Max date in db: 2020-02-28
# Min date in file: 2019-08-13
# Conflict !!!
# Records count for import: 411
# Now min date in file: 2020-03-03
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/19396526 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1214
# DB contains edrpou: 19396526
# Max date in db: 2020-08-10
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 323
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/25046658 реалізація МНОГО.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 22681
# DB contains edrpou: 25046658
# Max date in db: 2020-07-31
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 5335
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/31955805 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 5440
# DB contains edrpou: 31955805
# Max date in db: 2020-07-31
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 1235
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/35935562 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 305
# DB contains edrpou: 35935562
# Max date in db: 2020-07-30
# Min date in file: 2019-10-21
# Conflict !!!
# Records count for import: 71
# Now min date in file: 2020-08-15
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/36068718 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 995
# DB contains edrpou: 36068718
# Max date in db: 2020-06-30
# Min date in file: 2019-10-18
# Conflict !!!
# Records count for import: 172
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/36703454 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1549
# DB contains edrpou: 36703454
# Max date in db: 2020-07-31
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 411
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/36997771 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 480
# DB contains edrpou: 36997771
# Max date in db: 2020-07-31
# Min date in file: 2019-10-21
# Conflict !!!
# Records count for import: 53
# Now min date in file: 2020-08-21
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/37725526 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 829
# DB contains edrpou: 37725526
# Max date in db: 2020-07-07
# Min date in file: 2019-10-17
# Conflict !!!
# Records count for import: 120
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/37827970 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 718
# DB contains edrpou: 37827970
# Max date in db: 2020-07-15
# Min date in file: 2020-01-03
# Conflict !!!
# Records count for import: 333
# Now min date in file: 2020-07-16
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/38133170 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 104
# DB contains edrpou: 38133170
# Max date in db: 2020-07-16
# Min date in file: 2019-10-17
# Conflict !!!
# Records count for import: 59
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/38185522 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 3406
# DB contains edrpou: 38185522
# Max date in db: 2020-08-06
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 791
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/38235159 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1192
# DB contains edrpou: 38235159
# Max date in db: 2020-07-31
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 500
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/38264719 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 3190
# DB contains edrpou: 38264719
# Max date in db: 2020-07-31
# Min date in file: 2019-10-22
# Conflict !!!
# Records count for import: 576
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/38388904 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 3103
# DB contains edrpou: 38388904
# Max date in db: 2020-07-31
# Min date in file: 2019-10-24
# Conflict !!!
# Records count for import: 1304
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/38453790 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1423
# DB contains edrpou: 38453790
# Max date in db: 2020-07-24
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 322
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/38797324 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 15305
# DB contains edrpou: 38797324
# Max date in db: 2020-08-06
# Min date in file: 2019-09-17
# Conflict !!!
# Records count for import: 1878
# Now min date in file: 2020-08-07
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/39031869 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1120
# DB contains edrpou: 39031869
# Max date in db: 2020-07-31
# Min date in file: 2019-10-24
# Conflict !!!
# Records count for import: 218
# Now min date in file: 2020-08-13
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/39043764 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 1014
# DB contains edrpou: 39043764
# Max date in db: 2020-07-14
# Min date in file: 2019-10-16
# Conflict !!!
# Records count for import: 238
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/39120419 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 5852
# DB contains edrpou: 39120419
# Max date in db: 2020-07-15
# Min date in file: 2019-10-25
# Conflict !!!
# Records count for import: 1313
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/39185764 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 997
# DB contains edrpou: 39185764
# Max date in db: 2020-07-15
# Min date in file: 2019-10-23
# Conflict !!!
# Records count for import: 265
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/39274670 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 43
# DB contains edrpou: 39274670
# Max date in db: 2020-06-16
# Min date in file: 2019-08-12
# Conflict !!!
# Records count for import: 0
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/39773126 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 5447
# DB contains edrpou: 39773126
# Max date in db: 2020-08-07
# Min date in file: 2019-12-02
# Conflict !!!
# Records count for import: 1826
# Now min date in file: 2020-08-08
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/39781472 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 4777
# DB contains edrpou: 39781472
# Max date in db: 2020-07-30
# Min date in file: 2019-10-17
# Conflict !!!
# Records count for import: 809
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/40109330 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 815
# DB contains edrpou: 40109330
# Max date in db: 2020-07-31
# Min date in file: 2019-10-17
# Conflict !!!
# Records count for import: 172
# Now min date in file: 2020-08-15
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/40380511 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 14780
# DB contains edrpou: 40380511
# Max date in db: 2020-07-15
# Min date in file: 2019-09-19
# Conflict !!!
# Records count for import: 1984
# Now min date in file: 2020-08-01
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/40407323 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 656
# DB contains edrpou: 40407323
# Max date in db: 2020-08-04
# Min date in file: 2019-10-17
# Conflict !!!
# Records count for import: 176
# Now min date in file: 2020-08-14
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/41047380 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 6115
# DB contains edrpou: 41047380
# Max date in db: 2020-07-27
# Min date in file: 2019-09-16
# Conflict !!!
# Records count for import: 1984
# Now min date in file: 2020-08-01
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/41189553 реалізація ВПП.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 23523
# DB contains edrpou: 41189553
# Max date in db: 2020-08-05
# Min date in file: 2020-01-22
# Conflict !!!
# Records count for import: 1889
# Now min date in file: 2020-08-06
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/41455095 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 459
# DB contains edrpou: 41455095
# Max date in db: 2020-07-30
# Min date in file: 2019-10-21
# Conflict !!!
# Records count for import: 126
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/41915774 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 52
# No data in db. Doing import whole file...
# Records count for import: 52
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/41987990 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 213
# DB contains edrpou: 41987990
# Max date in db: 2020-08-11
# Min date in file: 2019-11-21
# Conflict !!!
# Records count for import: 57
# Now min date in file: 2020-08-13
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/42346980 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 14754
# DB contains edrpou: 42346980
# Max date in db: 2020-07-31
# Min date in file: 2019-10-01
# Conflict !!!
# Records count for import: 1984
# Now min date in file: 2020-08-01
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/42853693 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 2887
# DB contains edrpou: 42853693
# Max date in db: 2020-07-29
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 643
# Now min date in file: 2020-08-12
# Done.
# Work with /home/das/db_develop/nalog_copy/2020.11.09/DropMeFiles_MGyKv/42918383 реалізація.xlsx:
# Read excel file
# Deleted 0 duplicates
# Rows count: 821
# DB contains edrpou: 42918383
# Max date in db: 2020-07-30
# Min date in file: 2019-11-01
# Conflict !!!
# Records count for import: 171
# Now min date in file: 2020-08-13
# Done.
# Work finished

# %%
tableName = "credit_staging"

# Пример пути all_files = glob.glob("F:/anamnez/in/**/ПЗ*.csv", recursive=True)
#pathes=["F:/anamnez/in/2020.03.20/**/ПЗ*.csv","F:/anamnez/in/2020.05.01/10 не вігрузило пз 38397840/**/ПЗ*.csv","F:/anamnez/in/2020.08.12/15/**/*реалізація*.xlsx","F:/anamnez/in/2020.08.12/46/**/*реалізація*.xlsx"]
#pathes=["F:/anamnez/in/2020.08.12/46/**/41189553 реалізація*.xlsx","F:/anamnez/in/2020.05.01/10 не вігрузило пз 38397840/**/пз 41189553.csv",]
pathes=["/home/das/db_develop/nalog_copy/2019.05.07/**/кредит.*",
        "/home/das/db_develop/nalog_copy/2020.03.20/**/*ПК*.*",
        "/home/das/db_develop/nalog_copy/2020.05.01/**/*пк*.*",
        "/home/das/db_develop/nalog_copy/2020.05.20/**/*пк*.*",
        "/home/das/db_develop/nalog_copy/2020.08.12/**/*придбання*.*",
        "/home/das/db_develop/nalog_copy/2020.11.09/**/*придбання*.*"
       ]
all_pths_credit=[]
for pth in pathes:
    for p in glob.glob(pth, recursive=True):
        #print(p)
        all_pths_credit.append(p)
    #print(len(glob.glob(pth, recursive=True)))
all_pths_credit= sorted(all_pths_credit)
print(len(all_pths_credit))
print(all_pths_credit)
# Out:
# 221
# ['/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/19156740/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/22954177/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/24908218 (ЮГОВОСТОК)/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/25046658/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/25288344 (КИЙ-В)/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/33358979/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/36303331/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/37069288 (ТЕХМА)/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/38388904/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/39527778/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/40295657 (МЕТСЕЙЛ)/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009 (3)/40946602 (ЭФЕС)/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/35935562/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/36068718/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38185522/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38235159/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38453790/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/38797324/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39031869/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39304165/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/39386468/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/1009/41047380/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/19156740/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/22954177/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/24908218/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/25046658/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/25288344/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/33358979/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/35935562/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/36068718/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/36303331/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/37069288/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38185522/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38235159/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38388904/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38453790/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/38797324/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39031869/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39304165/кредит.xls', '/home/das/db_develop/nalog_copy/2019.05.07/nalog-files/Flexa/2017_первые 22 компании/39386468/кредит.xls', '/ho ...

# %%
for pth in all_pths_credit:
    df_firms_in_base = pd.read_sql('select buyer_edrpou as edrpou, max(ordering_date) AS maxdate from '+tableName+' GROUP BY buyer_edrpou', con=dbConnection)
    print(df_firms_in_base.head())
    pass
    db_edrpous = []
    if not df_firms_in_base.empty :
        db_edrpous=df_firms_in_base['edrpou'].tolist()
    all_files = glob.glob(pth, recursive=True)
    for filename in all_files:
        print("Work with " + filename +": ")
        if (filename.find('.csv')>0):
            print("Read csv file")
            frame = pd.read_csv(filename, engine="python", encoding="cp1251", sep=';', decimal=",")
            frame['Дата виписки'] = pd.to_datetime(frame['Дата виписки'],format='%d.%m.%Y', errors='raise')
        else:
            print("Read excel file")
            if (filename.find('.xls')>0):
                frame = pd.read_excel(filename)
            else:
                print("Wrong file type")
                exit()
        
        frame['Дата виписки'] = frame['Дата виписки'].dt.strftime('%Y-%m-%d')
        frame = frame.rename(columns={ \
                                      "Область (Продавець)": "Регіон (Продавець)", \
                                      "Податковий № (Продавець)": "Податковий номер (Продавець)", \
                                      "Область (Покупець)": "Регіон (Покупець)", \
                                      "Податковий № (Покупець)":"Податковий номер (Покупець)", \
                                      "Реєстраційний №":"Реєстр. номер у ЄРПН", \
                                      "Номер ПН/РК":"№ ПН", \
                                      "Ціна постачання одиниці товару / послуги без урахування податку на додану вартість":"Ціна постачання одиниці товару/послуги без ПДВ"})
        frame_rows_orig = frame.shape[0]
        frame.drop_duplicates(subset=['Податковий номер (Продавець)', 'Податковий номер (Покупець)', 'Номенклатура товарів/послуг','Кількість (об’єм , обсяг)','Ціна постачання одиниці товару/послуги без ПДВ'])
        frame_rows_nodup = frame.shape[0]
        print("Deleted " + str(frame_rows_orig - frame_rows_nodup)  +  " duplicates")
        frame.drop('Статус ПН/РК', axis=1, errors='ignore', inplace=True)
        frame.drop('Виключено', axis=1, errors='ignore', inplace=True)
        frame.drop('Обсяги постачання (база оподаткування) без урахування податку на додану вартість', axis=1, errors='ignore', inplace=True)
        print("Rows count: "+ str(len(frame['Дата виписки'])))
        frame = frame.rename(columns={
                'Iдентифікатор документа': 'doc_id',
            	'Регіон (Продавець)':'seller_region',
                'Район (Продавець)':'seller_rayon',
                'Податковий номер (Продавець)': 'seller_edrpou',
                'ІПН (Продавець)': 'seller_ipn',
                'Найменування/ПІБ (Продавець)': 'seller_name',
                'Стан (Продавець)': 'seller_state',
                'Регіон (Покупець)': 'buyer_region',
                'Район (Покупець)': 'buyer_rayon',
                'Податковий номер (Покупець)': 'buyer_edrpou',
                'ІПН (Покупець)': 'buyer_ipn',
                'Найменування/ПІБ (Покупець)': 'buyer_name',
                'Стан (Покупець)': 'buyer_state',
                'Реєстр. номер у ЄРПН': 'reestr_number',
                '№ ПН': 'nn_number',
                'Дата виписки': 'ordering_date',
                'Дата реєстрації': 'registration_date',
                'Загальна сума коштів що підлягає сплаті': 'total_pay_cost',
                'Сума ПДВ': 'pdv_summ',
                'Обсяг операцій за ставкою 20%': '20_percent_count',
                'Обсяг операцій за ставкою 7%': '7_percent_count',
                'Кількість РК': 'rk_count',
                'Сума коригування': 'correction_cost',
                'Ціна постач.одиниці РК': 'one_rk_cost',
                'Номенклатура товарів/послуг': 'product_name',
                'Код УКТЗЕД': 'product_code',
                'Одиниця виміру товару/ послуги': 'unit',
                'Кількість (об’єм , обсяг)': 'count',
                'Ціна постачання одиниці товару/послуги без ПДВ': 'one_product_cost'
                })
        frame['seller_edrpou'].replace({0.0:0})
        frame['buyer_edrpou'].replace({0.0:0})
        if 'reestr_number' in frame.columns:
            frame['reestr_number'].replace({0.0:0})
        frame['seller_edrpou'].fillna(value=0,inplace=True)
        frame['buyer_edrpou'].fillna(value=0,inplace=True)
        frame['hash'] = frame.apply(lambda x: hash(tuple(x)), axis = 1)

        if len(frame) > 0:
            file_edrpou=int(min(frame['buyer_edrpou']))
            if file_edrpou in db_edrpous:
                print("DB contains edrpou: "+ str(file_edrpou))
                min_file_date = str(min(frame['ordering_date']))
                max_db_date = str(df_firms_in_base[df_firms_in_base['edrpou'] == file_edrpou]['maxdate'].iloc[0])
                print("Max date in db: "+ max_db_date)
                print("Min date in file: "+min_file_date)
                if (max_db_date > min_file_date):
                    print ("Conflict !!!")
                    frame=frame[frame['ordering_date']>str(max_db_date)]
                    print("Records count for import: " + str(len(frame['ordering_date'])))
                    if len(frame) > 0:
                        print("Now min date in file: "+str(min(frame['ordering_date'])))
                        frame.to_sql(tableName, dbConnection, if_exists='append', index=False)
                else:  # if no conflicts
                    print("There are no conflicts. Doing import whole file...")
                    print("Records count for import: " + str(frame.shape[0]))
                    frame.to_sql(tableName, dbConnection, if_exists='append', index=False)
            else:  #if no data in db
                print("No data in db. Doing import whole file...")
                print("Records count for import: " + str(frame.shape[0]))
                frame.to_sql(tableName, dbConnection, if_exists='append', index=False)
            print("Done.")
        else:
            print("No data for period...")
print('Work finished')
